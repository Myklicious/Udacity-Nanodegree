# %% [markdown]
# # Exploring the EPA Data set in 2018 and 2008
# Use the space below to explore `all_alpha_08.csv` and `all_alpha_18.csv` to answer the quiz questions below.

# %%
#import packages
import numpy as np 
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')

# %matplotlib inline

# %%
#import CSV files
df_08 = pd.read_csv('Datasets/EPA/all_alpha_08.csv')
df_18 = pd.read_csv('Datasets/EPA/all_alpha_18.csv')

# %% [markdown]
# ## Explore the data set

# %%
df_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 2404 non-null   object
#  1   Displ                 2404 non-null   float64
#  2   Cyl                   2205 non-null   object
#  3   Trans                 2205 non-null   object
#  4   Drive                 2311 non-null   object
#  5   Fuel                  2404 non-null   object
#  6   Sales Area            2404 non-null   object
#  7   Stnd                  2404 non-null   object
#  8   Underhood ID          2404 non-null   object
#  9   Veh Class             2404 non-null   object
#  10  Air Pollution Score   2404 non-null   object
#  11  FE Calc Appr          2205 non-null   object
#  12  City MPG              2205 non-null   object
#  13  Hwy MPG               2205 non-null   object
#  14  Cmb MPG               2205 non-null   object
# ...

# %%
df_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 1611 non-null   object
#  1   Displ                 1609 non-null   float64
#  2   Cyl                   1609 non-null   float64
#  3   Trans                 1611 non-null   object
#  4   Drive                 1611 non-null   object
#  5   Fuel                  1611 non-null   object
#  6   Cert Region           1611 non-null   object
#  7   Stnd                  1611 non-null   object
#  8   Stnd Description      1611 non-null   object
#  9   Underhood ID          1611 non-null   object
#  10  Veh Class             1611 non-null   object
#  11  Air Pollution Score   1611 non-null   int64
#  12  City MPG              1611 non-null   object
#  13  Hwy MPG               1611 non-null   object
#  14  Cmb MPG               1611 non-null   object
# ...

# %%
#count duplicates
sum(df_18.duplicated())
# Out:
# 0

# %%
#rows with missing data
sum(df_18.isnull().any(axis=1))
# Out:
# 2

# %%
#find nonunique values in 2008 data
df_08.nunique()
# Out:
# Model                   436
# Displ                    47
# Cyl                       8
# Trans                    14
# Drive                     2
# Fuel                      5
# Sales Area                3
# Stnd                     12
# Underhood ID            343
# Veh Class                 9
# Air Pollution Score      13
# FE Calc Appr              2
# City MPG                 39
# Hwy MPG                  43
# Cmb MPG                  38
# Unadj Cmb MPG           721
# Greenhouse Gas Score     20
# SmartWay                  2
# dtype: int64

# %%
df_18.nunique()
# Out:
# Model                   367
# Displ                    36
# Cyl                       7
# Trans                    26
# Drive                     2
# Fuel                      5
# Cert Region               2
# Stnd                     19
# Stnd Description         19
# Underhood ID            230
# Veh Class                 9
# Air Pollution Score       6
# City MPG                 58
# Hwy MPG                  62
# Cmb MPG                  57
# Greenhouse Gas Score     10
# SmartWay                  3
# Comb CO2                299
# dtype: int64

# %%
df_08.head(1)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG Hwy MPG  \
# 0  8HNXT03.7PKR       SUV                   7          Drv       15      20
#
#   Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# 0      17        22.0527                    4       no

# %%
df_18.head(1)
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region    Stnd  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  T3B125
#
#          Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0  Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
#
#   City MPG Hwy MPG Cmb MPG  Greenhouse Gas Score SmartWay Comb CO2
# 0       20      28      23                     5       No      386

# %%
df_08['Fuel'].unique()
# Out:
# array(['Gasoline', 'ethanol/gas', 'ethanol', 'diesel', 'CNG'],
#       dtype=object)

# %%
df_18['Fuel'].unique()
# Out:
# array(['Gasoline', 'Gasoline/Electricity', 'Diesel', 'Ethanol/Gas',
#        'Electricity'], dtype=object)

# %% [markdown]
# ## Drop extraneous columns from data set

# %%
drop_08 = ['Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG']
drop_18 = ['Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2']
df_08.drop(drop_08, inplace = True, axis = 1)
df_18.drop(drop_18, inplace = True, axis = 1)

# %%
df_08.head(1)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Veh Class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA       SUV
#
#   Air Pollution Score City MPG Hwy MPG Cmb MPG Greenhouse Gas Score SmartWay
# 0                   7       15      20      17                    4       no

# %%
df_18.head(1)
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region  Veh Class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
#
#    Air Pollution Score City MPG Hwy MPG Cmb MPG  Greenhouse Gas Score SmartWay
# 0                    3       20      28      23                     5       No

# %% [markdown]
# ## Renaming columns for consistency

# %%
df_08.rename(columns = {'Sales Area': 'Cert Region'}, inplace = True)

df_08.head(1)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Cert Region Veh Class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA       SUV
#
#   Air Pollution Score City MPG Hwy MPG Cmb MPG Greenhouse Gas Score SmartWay
# 0                   7       15      20      17                    4       no

# %%
# replace spaces with underscores and lowercase labels for 2008 dataset
df_08.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)

# confirm changes
df_08.head(1)
# Out:
#        model  displ      cyl    trans drive      fuel cert_region veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA       SUV
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no

# %%
# replace spaces with underscores and lowercase labels for 2018 dataset
df_18.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)

# confirm changes
df_18.head(1)
# Out:
#        model  displ  cyl       trans drive      fuel cert_region  veh_class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 0                    3       20      28      23                     5       No

# %%
# confirm column labels for 2008 and 2018 datasets are identical
df_08.columns == df_18.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
# make sure they're all identical like this
(df_08.columns == df_18.columns).all()
# Out:
# True

# %%
df_08.to_csv('Datasets/EPA/data_08_v1.csv', index=False)
df_18.to_csv('Datasets/EPA/data_18_v1.csv', index=False)

# %% [markdown]
# ## Filter, drop nulls, and delete duplicates

# %%
# Filter to cars certified by california standards (cert_region = CA), and then drop cert_region
col = 'cert_region'
col_val = 'CA'
df_08 = df_08.query(f'{col} == "{col_val}"')
df_18 = df_18.query(f'{col} == "{col_val}"')

# %%
# drop certification region columns form both datasets
df_08.drop('cert_region', axis=1, inplace=True)
df_18.drop('cert_region', axis=1, inplace=True)

# %%
df_08.isna().sum()
# Out:
# model                    0
# displ                    0
# cyl                     75
# trans                   75
# drive                   37
# fuel                     0
# veh_class                0
# air_pollution_score      0
# city_mpg                75
# hwy_mpg                 75
# cmb_mpg                 75
# greenhouse_gas_score    75
# smartway                 0
# dtype: int64

# %%
df_18.isnull().sum()
# Out:
# model                   0
# displ                   1
# cyl                     1
# trans                   0
# drive                   0
# fuel                    0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
# drop rows with any null values in both datasets
df_08.dropna(inplace = True)
df_18.dropna(inplace = True)

# %% [markdown]
# ## Drop duplicates

# %%
print(f'duplicates 08: {df_08.duplicated().sum()}')
print(f'duplicates 18: {df_18.duplicated().sum()}')
# Out:
# duplicates 08: 23
# duplicates 18: 3

# %%
df_08.drop_duplicates(inplace = True)
df_18.drop_duplicates(inplace = True)

print(f'duplicates 08: {df_08.duplicated().sum()}')
print(f'duplicates 18: {df_18.duplicated().sum()}')
# Out:
# duplicates 08: 0
# duplicates 18: 0

# %%
# save progress for the next section
df_08.to_csv('Datasets/EPA/data_08_v2.csv', index=False)
df_18.to_csv('Datasets/EPA/data_18_v2.csv', index=False)

# %%
df_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 986 entries, 0 to 2400
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 986 non-null    object
#  1   displ                 986 non-null    float64
#  2   cyl                   986 non-null    object
#  3   trans                 986 non-null    object
#  4   drive                 986 non-null    object
#  5   fuel                  986 non-null    object
#  6   veh_class             986 non-null    object
#  7   air_pollution_score   986 non-null    object
#  8   city_mpg              986 non-null    object
#  9   hwy_mpg               986 non-null    object
#  10  cmb_mpg               986 non-null    object
#  11  greenhouse_gas_score  986 non-null    object
#  12  smartway              986 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 107.8+ KB

# %%
df_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 794 entries, 1 to 1609
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 794 non-null    object
#  1   displ                 794 non-null    float64
#  2   cyl                   794 non-null    float64
#  3   trans                 794 non-null    object
#  4   drive                 794 non-null    object
#  5   fuel                  794 non-null    object
#  6   veh_class             794 non-null    object
#  7   air_pollution_score   794 non-null    int64
#  8   city_mpg              794 non-null    object
#  9   hwy_mpg               794 non-null    object
#  10  cmb_mpg               794 non-null    object
#  11  greenhouse_gas_score  794 non-null    int64
#  12  smartway              794 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 86.8+ KB

# %%
df_08.head(1)
# Out:
#        model  displ      cyl    trans drive      fuel veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline       SUV
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no

# %%
df_18.head(1)
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline  small SUV
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 1                    3       20      28      23                     5       No

# %% [markdown]
# ## Fixing Data types

# %%
#check value counts for 2008 cyl column
df_08['cyl'].value_counts()
# Out:
# (6 cyl)     409
# (4 cyl)     283
# (8 cyl)     199
# (5 cyl)      48
# (12 cyl)     30
# (10 cyl)     14
# (2 cyl)       2
# (16 cyl)      1
# Name: cyl, dtype: int64

# %%
# Extract int from strings in the 2008 cyl column utilizing regular expressions
df_08['cyl'] = df_08['cyl'].str.extract('(\d+)').astype(int)

# %%
#check value counts for 2008 cyl column 
df_08['cyl'].value_counts()
# Out:
# 6     409
# 4     283
# 8     199
# 5      48
# 12     30
# 10     14
# 2       2
# 16      1
# Name: cyl, dtype: int64

# %%
#convert 2018 data from float to int with astype function
df_18['cyl'] = df_18['cyl'].astype(int)

# %%
df_08.to_csv('data_08_v3.csv', index=False)
df_18.to_csv('data_18_v3.csv', index=False)

# %% [markdown]
# ## Fixing air_pollution_score data type

# %%
# try using pandas' to_numeric or astype function to convert the
# 2008 air_pollution_score column to float -- this won't work
#df_08['air_pollution_score'].astype(float)

# %%
#filter to where only the following are available
df_08[df_08['air_pollution_score'] == '6/4']
# Out:
#                    model  displ  cyl    trans drive         fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %%
#extract all the hybrid vehicles from 2008
hb_08 = df_08[df_08['fuel'].str.contains('/')]
hb_08.head(5)
# Out:
#                    model  displ  cyl    trans drive         fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %%
#Create two copies of the data frame
df1 = hb_08.copy()
df2 = hb_08.copy()

# %%
# columns to split by "/"
split_columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])

# %%
# this dataframe holds info for the FIRST fuel type of the hybrid
# aka the values before the "/"s
df1
# Out:
#                    model  displ  cyl    trans drive     fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                   6       13      19      15                    7
#
#      smartway
# 1550       no

# %%
# this dataframe holds info for the SECOND fuel type of the hybrid
# aka the values after the "/"s
df2
# Out:
#                    model  displ  cyl    trans drive fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                   4       18      25      21                    6
#
#      smartway
# 1550       no

# %%
# combine dataframes to add to the original dataframe
new_rows = df1.append(df2)

# now we have separate rows for each fuel type of each vehicle!
new_rows
# Out:
#                    model  displ  cyl    trans drive     fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD      gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                   6       13      19      15                    7
# 1550                   4       18      25      21                    6
#
#      smartway
# 1550       no
# 1550       no

# %%
# drop the original hybrid rows
df_08.drop(hb_08.index, inplace=True)

# add in our newly separated rows
df_08 = df_08.append(new_rows, ignore_index=True)

# %%
# check that all the original hybrid rows with "/"s are gone
df_08[df_08['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_08.shape
# Out:
# (987, 13)

# %% [markdown]
# ## Repeat Process for 2018 Dataset

# %%
# hybrids in 2018
hb_18 = df_18[df_18['fuel'].str.contains('/')]
hb_18
# Out:
#                                   model  displ  cyl       trans drive  \
# 108                            BMW 330e    2.0    4  SemiAuto-8   2WD
# 160                            BMW 530e    2.0    4  SemiAuto-8   2WD
# 162                            BMW 530e    2.0    4  SemiAuto-8   4WD
# 188                            BMW 740e    2.0    4  SemiAuto-8   4WD
# 382                    CHEVROLET Impala    3.6    6  SemiAuto-6   2WD
# 394              CHEVROLET Silverado 15    4.3    6      Auto-6   2WD
# 396              CHEVROLET Silverado 15    4.3    6      Auto-6   4WD
# 398              CHEVROLET Silverado 15    5.3    8      Auto-6   2WD
# 428             CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD
# 432             CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD
# 436                CHEVROLET Tahoe 1500    5.3    8      Auto-6   2WD
# 440                CHEVROLET Tahoe 1500    5.3    8      Auto-6   4WD
# ...

# %%
df1 = hb_18.copy()
df2 = hb_18.copy()

df1.head(5)
# Out:
#                 model  displ  cyl       trans drive                  fuel  \
# 108          BMW 330e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 160          BMW 530e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 162          BMW 530e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 188          BMW 740e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 382  CHEVROLET Impala    3.6    6  SemiAuto-6   2WD           Ethanol/Gas
#
#      veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 108  small car                    3    28/66   34/78   30/71
# 160  small car                    7    27/70   31/75   29/72
# 162  small car                    7    27/66   31/68   28/67
# 188  large car                    3    25/62   29/68   27/64
# 382  large car                    5    14/18   20/28   16/22
#
#      greenhouse_gas_score smartway
# 108                    10      Yes
# 160                    10    Elite
# 162                    10    Elite
# ...

# %%
#split columns using apply and split function
split_columns = ['fuel', 'city_mpg', 'hwy_mpg', 'cmb_mpg']
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])

# %%
df1.head(5)
# Out:
#                 model  displ  cyl       trans drive      fuel  veh_class  \
# 108          BMW 330e    2.0    4  SemiAuto-8   2WD  Gasoline  small car
# 160          BMW 530e    2.0    4  SemiAuto-8   2WD  Gasoline  small car
# 162          BMW 530e    2.0    4  SemiAuto-8   4WD  Gasoline  small car
# 188          BMW 740e    2.0    4  SemiAuto-8   4WD  Gasoline  large car
# 382  CHEVROLET Impala    3.6    6  SemiAuto-6   2WD   Ethanol  large car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score  \
# 108                    3       28      34      30                    10
# 160                    7       27      31      29                    10
# 162                    7       27      31      28                    10
# 188                    3       25      29      27                     9
# 382                    5       14      20      16                     4
#
#     smartway
# 108      Yes
# 160    Elite
# 162    Elite
# 188      Yes
# 382       No

# %%
df2.head(5)
# Out:
#                 model  displ  cyl       trans drive         fuel  veh_class  \
# 108          BMW 330e    2.0    4  SemiAuto-8   2WD  Electricity  small car
# 160          BMW 530e    2.0    4  SemiAuto-8   2WD  Electricity  small car
# 162          BMW 530e    2.0    4  SemiAuto-8   4WD  Electricity  small car
# 188          BMW 740e    2.0    4  SemiAuto-8   4WD  Electricity  large car
# 382  CHEVROLET Impala    3.6    6  SemiAuto-6   2WD          Gas  large car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score  \
# 108                    3       66      78      71                    10
# 160                    7       70      75      72                    10
# 162                    7       66      68      67                    10
# 188                    3       62      68      64                     9
# 382                    5       18      28      22                     4
#
#     smartway
# 108      Yes
# 160    Elite
# 162    Elite
# 188      Yes
# ...

# %%
#combine data sets
new_rows = df1.append(df2)

# %%
new_rows.head(10)
# Out:
#                        model  displ  cyl       trans drive      fuel  \
# 108                 BMW 330e    2.0    4  SemiAuto-8   2WD  Gasoline
# 160                 BMW 530e    2.0    4  SemiAuto-8   2WD  Gasoline
# 162                 BMW 530e    2.0    4  SemiAuto-8   4WD  Gasoline
# 188                 BMW 740e    2.0    4  SemiAuto-8   4WD  Gasoline
# 382         CHEVROLET Impala    3.6    6  SemiAuto-6   2WD   Ethanol
# 394   CHEVROLET Silverado 15    4.3    6      Auto-6   2WD   Ethanol
# 396   CHEVROLET Silverado 15    4.3    6      Auto-6   4WD   Ethanol
# 398   CHEVROLET Silverado 15    5.3    8      Auto-6   2WD   Ethanol
# 428  CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD   Ethanol
# 432  CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD   Ethanol
#
#         veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 108     small car                    3       28      34      30
# 160     small car                    7       27      31      29
# ...

# %%
#drop the original hybrid rows
df_18.drop(hb_18.index, inplace = True)

# %%
#add the new separated rows
df_18 = df_18.append(new_rows, ignore_index = True)

# %%
sum(df_18['fuel'].str.contains('/'))
# Out:
# 0

# %%
df_18.shape
# Out:
# (832, 13)

# %% [markdown]
# ## Fix city_mpg, hwy_mpg, cmb_mpg datatypes

# %%
##convert string to floats

# %%
# convert mpg columns to floats
mpg_columns = ['city_mpg', 'hwy_mpg', 'cmb_mpg']
for c in mpg_columns:
    df_18[c] = df_18[c].astype(float)
    df_08[c] = df_08[c].astype(float)

# %% [markdown]
# ## Fix greenhouse_gas_score datatype
# 2008: convert from float to int

# %%
# convert from float to int
df_08['greenhouse_gas_score'] = df_08['greenhouse_gas_score'].astype(int)
#added following b/c of int32 vs int64 descrepency
df_18['greenhouse_gas_score'] = df_18['greenhouse_gas_score'].astype(int)

df_08['air_pollution_score'] = df_08['air_pollution_score'].astype(float)
df_18['air_pollution_score'] = df_18['air_pollution_score'].astype(float)

# %%
df_08.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int32
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                float64
# hwy_mpg                 float64
# cmb_mpg                 float64
# greenhouse_gas_score      int32
# smartway                 object
# dtype: object

# %%
df_18.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int32
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                float64
# hwy_mpg                 float64
# cmb_mpg                 float64
# greenhouse_gas_score      int32
# smartway                 object
# dtype: object

# %%
df_08.dtypes == df_18.dtypes
# Out:
# model                   True
# displ                   True
# cyl                     True
# trans                   True
# drive                   True
# fuel                    True
# veh_class               True
# air_pollution_score     True
# city_mpg                True
# hwy_mpg                 True
# cmb_mpg                 True
# greenhouse_gas_score    True
# smartway                True
# dtype: bool

# %% [markdown]
# ## Use histograms and scatterplots to explore cleaned data

# %%
df_08['cmb_mpg'].plot(kind = 'hist');

# %%
df_18['cmb_mpg'].plot(kind = 'hist');

# %%
df_18.plot(x = "greenhouse_gas_score", y = "cmb_mpg", kind = "scatter")

# %% [markdown]
# ### Q1: Are more unique models using alternative sources of fuel? By how much?

# %%
fuel_08 = df_08['fuel'].value_counts()
fuel_18 = df_18['fuel'].value_counts()
print(f'{fuel_08} \n\n {fuel_18}')
# Out:
# Gasoline    984
# gas           1
# CNG           1
# ethanol       1
# Name: fuel, dtype: int64
#
#  Gasoline       749
# Gas             26
# Ethanol         26
# Diesel          19
# Electricity     12
# Name: fuel, dtype: int64

# %%
alt_08 = df_08.query('fuel in ["CNG", "ethanol"]').model.nunique()
alt_18 = df_18.query('fuel in ["Ethanol", "Electricity"]').model.nunique()
alt_diff = alt_18 - alt_08
print(alt_diff)
# Out:
# 24

# %% [markdown]
# ### Q2: How much have vehicle classes improved in fuel economy?

# %%
veh_class_08 = df_08.groupby('veh_class').cmb_mpg.mean()
veh_class_18 = df_18.groupby('veh_class').cmb_mpg.mean()

print(f'{veh_class_08} \n\n {veh_class_18}')
# Out:
# veh_class
# SUV              18.471429
# large car        18.509091
# midsize car      21.601449
# minivan          19.117647
# pickup           16.277108
# small car        21.105105
# station wagon    22.366667
# van              14.952381
# Name: cmb_mpg, dtype: float64
#
#  veh_class
# large car          23.409091
# midsize car        27.884058
# minivan            20.800000
# pickup             18.589744
# small SUV          24.074074
# small car          25.421053
# special purpose    18.500000
# standard SUV       18.197674
# station wagon      27.529412
# Name: cmb_mpg, dtype: float64

# %%
imp = veh_class_18-veh_class_08
imp
# Out:
# veh_class
# SUV                     NaN
# large car          4.900000
# midsize car        6.282609
# minivan            1.682353
# pickup             2.312635
# small SUV               NaN
# small car          4.315948
# special purpose         NaN
# standard SUV            NaN
# station wagon      5.162745
# van                     NaN
# Name: cmb_mpg, dtype: float64

# %%
imp.dropna(inplace = True)

# %%
imp.plot(kind = 'bar', figsize = (8,5), title = 'Improvements in Fuel Economy from 2008 to 2018 by Vehicle Class' );

# %% [markdown]
# ### Q3: What are the characteristics of SmartWay vehicles? Have they changed over time?

# %%
smart_08 = df_08['smartway'].unique()
smart_18 = df_18['smartway'].unique()
print(f'{smart_08} /n/n {smart_18}')
# Out:
# ['no' 'yes'] /n/n ['No' 'Yes' 'Elite']

# %%
smart_08 = df_08.query('smartway == "yes"')
smart_18 = df_18.query('smartway in ["Yes", "Elite"]')

# %%
smart_08.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  380.000000  380.000000           380.000000  380.000000  380.000000
# mean     2.602895    4.826316             7.365789   20.984211   28.413158
# std      0.623436    1.002025             1.148195    3.442672    3.075194
# min      1.300000    4.000000             6.000000   17.000000   22.000000
# 25%      2.275000    4.000000             7.000000   19.000000   26.000000
# 50%      2.400000    4.000000             7.000000   20.000000   28.000000
# 75%      3.000000    6.000000             7.000000   22.000000   30.000000
# max      5.000000    8.000000             9.500000   48.000000   45.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  380.000000            380.000000
# mean    23.736842              6.868421
# std      3.060379              0.827338
# min     20.000000              6.000000
# 25%     22.000000              6.000000
# 50%     23.000000              7.000000
# ...

# %%
smart_18.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  108.000000  108.000000           108.000000  108.000000  108.000000
# mean     1.787963    3.935185             5.212963   34.907407   41.472222
# std      0.408031    0.416329             1.798498   16.431982   13.095236
# min      1.200000    3.000000             3.000000   25.000000   27.000000
# 25%      1.500000    4.000000             3.000000   28.000000   36.000000
# 50%      1.700000    4.000000             5.500000   28.500000   37.000000
# 75%      2.000000    4.000000             7.000000   31.250000   40.250000
# max      3.500000    6.000000             7.000000  113.000000   99.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  108.000000            108.000000
# mean    37.361111              7.925926
# std     14.848429              1.197378
# min     26.000000              7.000000
# 25%     31.000000              7.000000
# 50%     32.000000              7.000000
# ...

# %% [markdown]
# ### Q4: What features are associated with better fuel economy?

# %%
better_eco_08 = df_08.query('cmb_mpg > cmb_mpg.mean()')
better_eco_18 = df_18.query('cmb_mpg > cmb_mpg.mean()')

# %%
better_eco_08.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  519.000000  519.000000           519.000000  519.000000  519.000000
# mean     2.667823    4.890173             6.998073   20.317919   27.603083
# std      0.665551    1.034856             1.159565    3.198257    3.051120
# min      1.300000    4.000000             4.000000   17.000000   20.000000
# 25%      2.300000    4.000000             6.000000   18.000000   25.000000
# 50%      2.500000    4.000000             7.000000   20.000000   27.000000
# 75%      3.000000    6.000000             7.000000   21.000000   29.000000
# max      6.000000    8.000000             9.500000   48.000000   45.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  519.000000            519.000000
# mean    22.992293              6.639692
# std      2.926371              0.804935
# min     20.000000              6.000000
# 25%     21.000000              6.000000
# 50%     22.000000              6.000000
# ...

# %%
better_eco_18.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  328.000000  328.000000           328.000000  328.000000  328.000000
# mean     1.964329    4.021341             4.856707   27.472561   35.304878
# std      0.398593    0.465477             1.860802   11.033692    9.024857
# min      1.200000    3.000000             1.000000   21.000000   27.000000
# 25%      1.600000    4.000000             3.000000   23.000000   31.000000
# 50%      2.000000    4.000000             5.000000   25.000000   33.000000
# 75%      2.000000    4.000000             7.000000   28.000000   36.000000
# max      3.500000    6.000000             7.000000  113.000000   99.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  328.000000            328.000000
# mean    30.411585              6.329268
# std     10.081539              1.410358
# min     25.000000              4.000000
# 25%     26.000000              5.000000
# 50%     28.000000              6.000000
# ...

# %% [markdown]
# ### For all of the models that were produced in 2008 that are still being produced in 2018, how much has the mpg improved and which vehicle improved the most?

# %% [markdown]
# # Merging datasets

# %%
#rename all the columns
df_08_new = df_08.rename(columns = lambda x: x[:10] + '_08')
df_18_new = df_18.rename(columns = lambda x: x[:10] + '_18')

# %%
df_18_new.head(5)
# Out:
#     model_18  displ_18  cyl_18    trans_18 drive_18   fuel_18 veh_class_18  \
# 0  ACURA RDX       3.5       6  SemiAuto-6      2WD  Gasoline    small SUV
# 1  ACURA RDX       3.5       6  SemiAuto-6      4WD  Gasoline    small SUV
# 2  ACURA TLX       2.4       4       AMS-8      2WD  Gasoline    small car
# 3  ACURA TLX       3.5       6  SemiAuto-9      2WD  Gasoline    small car
# 4  ACURA TLX       3.5       6  SemiAuto-9      4WD  Gasoline    small car
#
#    air_pollut_18  city_mpg_18  hwy_mpg_18  cmb_mpg_18  greenhouse_18  \
# 0            3.0         20.0        28.0        23.0              5
# 1            3.0         19.0        27.0        22.0              4
# 2            3.0         23.0        33.0        27.0              6
# 3            3.0         20.0        32.0        24.0              5
# 4            3.0         21.0        30.0        24.0              5
#
#   smartway_18
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No

# %%
#merge datasets

# %%
df_merged = pd.merge(df_08_new, df_18_new, left_on = "model_08", right_on = "model_18", how = "inner")

# %%
df_merged.head(5)
# Out:
#     model_08  displ_08  cyl_08 trans_08 drive_08   fuel_08   veh_class_08  \
# 0  ACURA RDX       2.3       4  Auto-S5      4WD  Gasoline            SUV
# 1  ACURA RDX       2.3       4  Auto-S5      4WD  Gasoline            SUV
# 2    AUDI A3       2.0       4    Man-6      2WD  Gasoline  station wagon
# 3    AUDI A3       2.0       4    Man-6      2WD  Gasoline  station wagon
# 4    AUDI A3       2.0       4  Auto-S6      2WD  Gasoline  station wagon
#
#    air_pollut_08  city_mpg_08  hwy_mpg_08  ...    trans_18  drive_18  \
# 0            7.0         17.0        22.0  ...  SemiAuto-6       2WD
# 1            7.0         17.0        22.0  ...  SemiAuto-6       4WD
# 2            7.0         21.0        29.0  ...       AMS-6       4WD
# 3            7.0         21.0        29.0  ...       AMS-7       2WD
# 4            7.0         22.0        29.0  ...       AMS-6       4WD
#
#     fuel_18 veh_class_18  air_pollut_18  city_mpg_18 hwy_mpg_18 cmb_mpg_18  \
# ...

# %%
df_merged.shape
# Out:
# (922, 26)

# %%
df_merged.to_csv('Datasets/EPA/combined_EPA.csv', index=False)

# %% [markdown]
# # Results with Merged Dataset
# #### Q5: For all of the models that were produced in 2008 that are still being produced now, how much has the mpg improved and which vehicle improved the most?

# %%
df_merged.dtypes
# Out:
# model_08          object
# displ_08         float64
# cyl_08             int32
# trans_08          object
# drive_08          object
# fuel_08           object
# veh_class_08      object
# air_pollut_08    float64
# city_mpg_08      float64
# hwy_mpg_08       float64
# cmb_mpg_08       float64
# greenhouse_08      int32
# smartway_08       object
# model_18          object
# displ_18         float64
# cyl_18             int32
# trans_18          object
# drive_18          object
# fuel_18           object
# veh_class_18      object
# air_pollut_18    float64
# city_mpg_18      float64
# hwy_mpg_18       float64
# cmb_mpg_18       float64
# greenhouse_18      int32
# smartway_18       object
# dtype: object

# %%
model_mpg = df_merged.groupby('model_08').mean()[['cmb_mpg_08', 'cmb_mpg_18']]

# %%
model_mpg.head(5)
# Out:
#            cmb_mpg_08  cmb_mpg_18
# model_08
# ACURA RDX   19.000000   22.500000
# AUDI A3     23.333333   28.000000
# AUDI A4     21.000000   27.000000
# AUDI A6     19.666667   25.666667
# AUDI A8 L   16.500000   22.000000

# %%
model_mpg['cmb_mpg_change'] = model_mpg['cmb_mpg_18'] - model_mpg['cmb_mpg_08']

# %%
model_mpg.head(5)
# Out:
#            cmb_mpg_08  cmb_mpg_18  cmb_mpg_change
# model_08
# ACURA RDX   19.000000   22.500000        3.500000
# AUDI A3     23.333333   28.000000        4.666667
# AUDI A4     21.000000   27.000000        6.000000
# AUDI A6     19.666667   25.666667        6.000000
# AUDI A8 L   16.500000   22.000000        5.500000

# %%
max_change = model_mpg['cmb_mpg_change'].max()
print(max_change)
# Out:
# 16.53333333333334

# %%
model_mpg.query(f'cmb_mpg_change == {max_change}')
# Out:
#              cmb_mpg_08  cmb_mpg_18  cmb_mpg_change
# model_08
# VOLVO XC 90   15.666667        32.2       16.533333
